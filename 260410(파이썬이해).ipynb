# %%
i=0
while True:
  i+=1
  if i==3:
    continue
  if i==10:
    break

  print(i)
# Out:
# 1
# 2
# 4
# 5
# 6
# 7
# 8
# 9

# %%
a=[1,2,3]
b=['apple', 'banana']
c=[1,'hi',3.14,[10,20]]
d=[]

# %%
b[1]
# Out:
# 'banana'

# %%
c[3]
# Out:
# [10, 20]

# %%
d
# Out:
# []

# %%
list(reversed(a))
# Out:
# [5, 4, 3, 2, 1]

# %%
a.append(0)

# %%
sorted(a)
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
a.append(4)

# %%
a[4]=5

# %%
a
# Out:
# [1, 2, 3, 4, 5]

# %%
fruits = ["apple", "banana", "cherry"]

# %%
fruits.extend([
    "orange", "mango", "grape", "peach", "strawberry",
    "pineapple", "kiwi", "watermelon", "blueberry", "pear"
])

# %%
len(fruits)
# Out:
# 13

# %%
for a in fruits:
    print(a)
# Out:
# apple
# banana
# cherry
# orange
# mango
# grape
# peach
# strawberry
# pineapple
# kiwi
# watermelon
# blueberry
# pear

# %%
upper_fruits = []

for fruit in fruits:
    upper_fruits.append(fruit.upper())

print(upper_fruits)
# Out:
# ['APPLE', 'BANANA', 'CHERRY', 'ORANGE', 'MANGO', 'GRAPE', 'PEACH', 'STRAWBERRY', 'PINEAPPLE', 'KIWI', 'WATERMELON', 'BLUEBERRY', 'PEAR']

# %%
for i, fruit in enumerate(fruits):
  i+=1
  print(f"{i}, {fruit}")
# Out:
# 1, apple
# 2, banana
# 3, cherry
# 4, orange
# 5, mango
# 6, grape
# 7, peach
# 8, strawberry
# 9, pineapple
# 10, kiwi
# 11, watermelon
# 12, blueberry
# 13, pear

# %%
kings = [
    "태조", "정종", "태종", "세종", "문종", "단종", "세조", "예종", "성종",
    "연산군", "중종", "인종", "명종", "선조", "광해군", "인조", "효종", "현종", "숙종",
    "경종", "영조", "정조", "순조", "헌종", "철종", "고종", "순종"
]

# %%
for i,king in enumerate(kings,start=1):
  print(f'{i},대왕,{king}')
# Out:
# 1,대왕,태조
# 2,대왕,정종
# 3,대왕,태종
# 4,대왕,세종
# 5,대왕,문종
# 6,대왕,단종
# 7,대왕,세조
# 8,대왕,예종
# 9,대왕,성종
# 10,대왕,연산군
# 11,대왕,중종
# 12,대왕,인종
# 13,대왕,명종
# 14,대왕,선조
# 15,대왕,광해군
# 16,대왕,인조
# 17,대왕,효종
# 18,대왕,현종
# 19,대왕,숙종
# 20,대왕,경종
# 21,대왕,영조
# 22,대왕,정조
# 23,대왕,순조
# 24,대왕,헌종
# 25,대왕,철종
# 26,대왕,고종
# 27,대왕,순종

# %%
a=int(input('몇대왕인지 입력하세요'))
print(f'{kings[a-1]}')
# Out:
# 몇대왕인지 입력하세요10
# 연산군

# %%
name = input("왕 이름을 입력하세요: ")
if name in kings :
  nht=kings.index(name)+1
  print(f"{name}은 조선{nht}대 왕입니다.")
else:
  print("그왕은 없습니다.")
# Out:
# 왕 이름을 입력하세요: 연산군
# 연산군은 조선10대 왕입니다.

# %%
#산지니 수정
for i, king in enumerate(kings, start=1):
    print(f"{i:>2}대왕  {king}")
# Out:
#  1대왕  태조
#  2대왕  정종
#  3대왕  태종
#  4대왕  세종
#  5대왕  문종
#  6대왕  단종
#  7대왕  세조
#  8대왕  예종
#  9대왕  성종
# 10대왕  연산군
# 11대왕  중종
# 12대왕  인종
# 13대왕  명종
# 14대왕  선조
# 15대왕  광해군
# 16대왕  인조
# 17대왕  효종
# 18대왕  현종
# 19대왕  숙종
# 20대왕  경종
# 21대왕  영조
# 22대왕  정조
# 23대왕  순조
# 24대왕  헌종
# 25대왕  철종
# 26대왕  고종
# 27대왕  순종

# %%
#산지니 수정 #범위오류 제거
a = int(input("몇 대 왕인지 입력하세요: "))

if 1 <= a <= len(joseon_kings):
    print(joseon_kings[a-1])
else:
    print("1부터", len(joseon_kings), "사이 숫자를 입력하세요.")

# %%
for i in list(reversed(kings)):
  print(i)
# Out:
# 순종
# 고종
# 철종
# 헌종
# 순조
# 정조
# 영조
# 경종
# 숙종
# 현종
# 효종
# 인조
# 광해군
# 선조
# 명종
# 인종
# 중종
# 연산군
# 성종
# 예종
# 세조
# 단종
# 문종
# 세종
# 태종
# 정종
# 태조

# %%
for i in range(len(kings)-1,-1,-1):
  print(kings[i])
# Out:
# 순종
# 고종
# 철종
# 헌종
# 순조
# 정조
# 영조
# 경종
# 숙종
# 현종
# 효종
# 인조
# 광해군
# 선조
# 명종
# 인종
# 중종
# 연산군
# 성종
# 예종
# 세조
# 단종
# 문종
# 세종
# 태종
# 정종
# 태조
